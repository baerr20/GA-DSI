# %%
import pandas as pd
import requests
import json
import urllib
import numpy as np
import json
import re
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !pip install imdbpie

# %%
from imdbpie import Imdb
imdb = Imdb()
imdb = Imdb(anonymize=True)

# %%
df = pd.DataFrame(imdb.top_250())
df
# Out:
#     can_rate                                              image  num_votes  \
# 0       True  {u'url': u'https://images-na.ssl-images-amazon...    1722313
# 1       True  {u'url': u'https://images-na.ssl-images-amazon...    1177083
# 2       True  {u'url': u'https://images-na.ssl-images-amazon...     806858
# 3       True  {u'url': u'https://images-na.ssl-images-amazon...    1708113
# 4       True  {u'url': u'https://images-na.ssl-images-amazon...     459014
# 5       True  {u'url': u'https://images-na.ssl-images-amazon...     882071
# 6       True  {u'url': u'https://images-na.ssl-images-amazon...    1349282
# 7       True  {u'url': u'https://images-na.ssl-images-amazon...    1237440
# 8       True  {u'url': u'https://images-na.ssl-images-amazon...     512706
# 9       True  {u'url': u'https://images-na.ssl-images-amazon...    1374786
# 10      True  {u'url': u'https://images-na.ssl-images-amazon...    1260035
# ...

# %%
imdb.top_250()
# Out:
# [{u'can_rate': True,
#   u'image': {u'height': 1388,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BODU4MjU4NjIwNl5BMl5BanBnXkFtZTgwMDU2MjEyMDE@._V1_.jpg',
#    u'width': 933},
#   u'num_votes': 1722313,
#   u'rating': 9.3,
#   u'tconst': u'tt0111161',
#   u'title': u'The Shawshank Redemption',
#   u'type': u'feature',
#   u'year': u'1994'},
#  {u'can_rate': True,
#   u'image': {u'height': 1129,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNTUxOTdjMDMtMWY1MC00MjkxLTgxYTMtYTM1MjU5ZTJlNTZjXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_.jpg',
#    u'width': 798},
#   u'num_votes': 1177083,
#   u'rating': 9.2,
#   u'tconst': u'tt0068646',
#   u'title': u'The Godfather',
#   u'type': u'feature',
#   u'year': u'1972'},
#  {u'can_rate': True,
#   u'image': {u'height': 1140,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNDVjZjgxNTgtMGNhMC00YWU0LTg0YTQtNTkxNzBjMDBkNWYyXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_.jpg',
#    u'width': 800},
# ...

# %%
person = imdb.get_person_by_id()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-e5b44244839a> in <module>()
# ----> 1 person = imdb.get_person_by_id()
#
# TypeError: get_person_by_id() takes exactly 2 arguments (1 given)

# %%
af = df.iloc[:,[3,5,7]]
af.head()
# Out:
#            Director                                          Language  \
# 0   Damien Chazelle                                           English
# 1    Akira Kurosawa                                          Japanese
# 2  Steven Spielberg  English, German, Hebrew, Spanish, Arabic, Nepali
# 3        David Lean                           English, Japanese, Thai
# 4       Joss Whedon                                  English, Russian
#
#                                                 Plot
# 0  A promising young drummer enrolls at a cut-thr...
# 1  A poor village under attack by bandits recruit...
# 2  Archaeologist and adventurer Indiana Jones is ...
# 3  After settling his differences with a Japanese...
# 4  Earth's mightiest heroes must come together an...

# %%
imdb_base_url = 'http://www.omdbapi.com/?'

# %%
imdb_response = requests.get(imdb_base_url)
imdb_response.text[:200]
# Out:
# u'\r\n<!DOCTYPE html>\r\n<html lang="en">\r\n<head>\r\n    <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\r\n    <meta charset="utf-8">\r\n    <title>OMDb API - The Open Movie Database</title>\r'

# %%
response = json.loads(imdb_response.text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-f089a52b8a65> in <module>()
# ----> 1 response = json.loads(imdb_response.text)
#
# /Applications/anaconda/lib/python2.7/json/__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337             parse_int is None and parse_float is None and
#     338             parse_constant is None and object_pairs_hook is None and not kw):
# --> 339         return _default_decoder.decode(s)
#     340     if cls is None:
#     341         cls = JSONDecoder
#
# /Applications/anaconda/lib/python2.7/json/decoder.pyc in decode(self, s, _w)
#     362
#     363         """
# --> 364         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     365         end = _w(s, end).end()
#     366         if end != len(s):
#
# ...

# %%
def get_top_250():
    response = requests.get('http://www.imdb.com/chart/top')
    html = response.text
    entries = re.findall("<a href.*?/title/(.*?)/", html)
    return list(set(entries))

# %%
entries = get_top_250()

# %%
def get_entry(entry):
    res = requests.get('http://www.omdbapi.com/?i='+entry)
    if res.status_code != 200:
        print entry, res.status_code
    else:
        print '.',
    try:
        j = json.loads(res.text)
    except ValueError:
        j = None
    return j

# %%
entries_dict_list = [get_entry(e) for e in entries]
# Out:
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .

# %%
df = pd.DataFrame(entries_dict_list)
df.head()
# Out:
#                                               Actors  \
# 0  Miles Teller, J.K. Simmons, Paul Reiser, Melis...
# 1  Toshirô Mifune, Takashi Shimura, Keiko Tsushim...
# 2  Harrison Ford, Karen Allen, Paul Freeman, Rona...
# 3  William Holden, Alec Guinness, Jack Hawkins, S...
# 4  Robert Downey Jr., Chris Evans, Mark Ruffalo, ...
#
#                                               Awards  Country  \
# 0   Won 3 Oscars. Another 87 wins & 131 nominations.      USA
# 1  Nominated for 2 Oscars. Another 5 wins & 6 nom...    Japan
# 2    Won 4 Oscars. Another 30 wins & 23 nominations.      USA
# 3     Won 7 Oscars. Another 23 wins & 7 nominations.  UK, USA
# 4  Nominated for 1 Oscar. Another 34 wins & 75 no...      USA
#
#            Director                     Genre  \
# 0   Damien Chazelle              Drama, Music
# 1    Akira Kurosawa  Action, Adventure, Drama
# 2  Steven Spielberg         Action, Adventure
# 3        David Lean     Adventure, Drama, War
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 20 columns):
# Actors        250 non-null object
# Awards        250 non-null object
# Country       250 non-null object
# Director      250 non-null object
# Genre         250 non-null object
# Language      250 non-null object
# Metascore     250 non-null object
# Plot          250 non-null object
# Poster        250 non-null object
# Rated         250 non-null object
# Released      250 non-null object
# Response      250 non-null object
# Runtime       250 non-null object
# Title         250 non-null object
# Type          250 non-null object
# Writer        250 non-null object
# Year          250 non-null object
# imdbID        250 non-null object
# imdbRating    250 non-null object
# imdbVotes     250 non-null object
# dtypes: object(20)
# memory usage: 39.1+ KB

# %%
def get_gross(entry):
    response = requests.get('http://www.imdb.com/title/'+entry)
    html = response.text
    try:
        gross_list = re.findall("Gross:</h4>[ ]*\$([^ ]*)", html)
        gross = int(gross_list[0].replace(',', ''))
        print '.',
        return gross
    except Exception as ex:
        print
        print ex, entry, response.status_code
        return None

# %%
grosses = [(e, get_gross(e)) for e in entries]
# Out:
# . . . . . . .
# list index out of range tt0046268 200
#
# list index out of range tt0055630 200
# . . . . .
# list index out of range tt0057115 200
# .
# list index out of range tt0071315 200
# . . . .
# list index out of range tt0074896 200
# . .
# list index out of range tt0021749 200
# . .
# list index out of range tt0053125 200
# . . .
# list index out of range tt1220719 200
#
# list index out of range tt0025316 200
# . .
# list index out of range tt0083922 200
# . . .
# list index out of range tt0072684 200
# .
# list index out of range tt0074958 200
# . . . .
# list index out of range tt0036775 200
# . . . . . .
# list index out of range tt0978762 200
# . .
# list index out of range tt0080678 200
# . .
# list index out of range tt0056592 200
# .
# list index out of range tt0095327 200
# . . . . . . . . .
# list index out of range tt0046438 200
# .
# list index out of range tt0015864 200
# .
# list index out of range tt0045152 200
# . . . .
# ...

# %%
df1 = pd.DataFrame(grosses, columns=['imdbID', 'Gross'])
df1.head()
# Out:
#       imdbID        Gross
# 0  tt2582802   13092000.0
# 1  tt0047478     269061.0
# 2  tt0082971  242374454.0
# 3  tt0050212   27200000.0
# 4  tt0848228  623279547.0

# %%
df = df.replace('N/A', np.nan)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 20 columns):
# Actors        250 non-null object
# Awards        246 non-null object
# Country       250 non-null object
# Director      250 non-null object
# Genre         250 non-null object
# Language      249 non-null object
# Metascore     169 non-null object
# Plot          250 non-null object
# Poster        248 non-null object
# Rated         249 non-null object
# Released      249 non-null object
# Response      250 non-null object
# Runtime       250 non-null object
# Title         250 non-null object
# Type          250 non-null object
# Writer        250 non-null object
# Year          250 non-null object
# imdbID        250 non-null object
# imdbRating    250 non-null object
# imdbVotes     250 non-null object
# dtypes: object(20)
# memory usage: 39.1+ KB

# %%
df.Released = pd.to_datetime(df.Released)

# %%
def intminutes(x):
    y = x.replace('min', '').strip()
    return int(y)

df.Runtime = df.Runtime.apply(intminutes)

# %%
df.Year = df.Year.astype(int)

# %%
df.imdbRating = df.imdbRating.astype(float)

# %%
def intvotes(x):
    y = x.replace(',', '').strip()
    return int(y)
df.imdbVotes = df.imdbVotes.apply(intvotes)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 20 columns):
# Actors        250 non-null object
# Awards        246 non-null object
# Country       250 non-null object
# Director      250 non-null object
# Genre         250 non-null object
# Language      249 non-null object
# Metascore     169 non-null object
# Plot          250 non-null object
# Poster        248 non-null object
# Rated         249 non-null object
# Released      249 non-null datetime64[ns]
# Response      250 non-null object
# Runtime       250 non-null int64
# Title         250 non-null object
# Type          250 non-null object
# Writer        250 non-null object
# Year          250 non-null int64
# imdbID        250 non-null object
# imdbRating    250 non-null float64
# imdbVotes     250 non-null int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(15)
# memory usage: 39.1+ KB

# %%
df = pd.merge(df, df1)

# %%
df.head()
# Out:
#                                               Actors  \
# 0  Miles Teller, J.K. Simmons, Paul Reiser, Melis...
# 1  Toshirô Mifune, Takashi Shimura, Keiko Tsushim...
# 2  Harrison Ford, Karen Allen, Paul Freeman, Rona...
# 3  William Holden, Alec Guinness, Jack Hawkins, S...
# 4  Robert Downey Jr., Chris Evans, Mark Ruffalo, ...
#
#                                               Awards  Country  \
# 0   Won 3 Oscars. Another 87 wins & 131 nominations.      USA
# 1  Nominated for 2 Oscars. Another 5 wins & 6 nom...    Japan
# 2    Won 4 Oscars. Another 30 wins & 23 nominations.      USA
# 3     Won 7 Oscars. Another 23 wins & 7 nominations.  UK, USA
# 4  Nominated for 1 Oscar. Another 34 wins & 75 no...      USA
#
#            Director                     Genre  \
# 0   Damien Chazelle              Drama, Music
# 1    Akira Kurosawa  Action, Adventure, Drama
# 2  Steven Spielberg         Action, Adventure
# 3        David Lean     Adventure, Drama, War
# ...

# %%
del df['Plot']
del df ['Poster']
del df ['Type']

# %%
#add to above del
del df ['Response']

# %%
df.head(20)
# Out:
#                                                Actors  \
# 0   Miles Teller, J.K. Simmons, Paul Reiser, Melis...
# 1   Toshirô Mifune, Takashi Shimura, Keiko Tsushim...
# 2   Harrison Ford, Karen Allen, Paul Freeman, Rona...
# 3   William Holden, Alec Guinness, Jack Hawkins, S...
# 4   Robert Downey Jr., Chris Evans, Mark Ruffalo, ...
# 5   Leonardo DiCaprio, Tom Hardy, Domhnall Gleeson...
# 6   Andy Lau, Tony Chiu Wai Leung, Anthony Chau-Sa...
# 7   Yves Montand, Charles Vanel, Folco Lulli, Pete...
# 8   Toshirô Mifune, Tatsuya Nakadai, Yôko Tsukasa,...
# 9   Albert Brooks, Ellen DeGeneres, Alexander Goul...
# 10  Bette Davis, Anne Baxter, George Sanders, Cele...
# 11  John Goodman, Billy Crystal, Mary Gibbs, Steve...
# 12  Chris Hemsworth, Daniel Brühl, Olivia Wilde, A...
# 13  Clint Eastwood, Hilary Swank, Morgan Freeman, ...
# 14  Steve McQueen, James Garner, Richard Attenboro...
# 15  Adrien Brody, Emilia Fox, Michal Zebrowski, Ed...
# ...

# %%
df['Oscars'] = df['Awards'].apply(lambda x: x.split('.'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-142-43000c4db287> in <module>()
# ----> 1 df['Oscars'] = df['Awards'].apply(lambda x: x.split('.'))
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2218         else:
#    2219             values = self.asobject
# -> 2220             mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2221
#    2222         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:62658)()
#
# <ipython-input-142-43000c4db287> in <lambda>(x)
# ----> 1 df['Oscars'] = df['Awards'].apply(lambda x: x.split('.'))
#
# AttributeError: 'float' object has no attribute 'split'

# %%
df['Oscars'] = pd.DataFrame(df.Awards.str.split('.').tolist())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-146-b1da3f9030e6> in <module>()
# ----> 1 df['Oscars'] = pd.DataFrame(df.Awards.str.split('.').tolist())
#       2
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     261                     if com.is_named_tuple(data[0]) and columns is None:
#     262                         columns = data[0]._fields
# --> 263                     arrays, columns = _to_arrays(data, columns, dtype=dtype)
#     264                     columns = _ensure_index(columns)
#     265
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _to_arrays(data, columns, coerce_float, dtype)
#    5350     if isinstance(data[0], (list, tuple)):
#    5351         return _list_to_arrays(data, columns, coerce_float=coerce_float,
# ...

# %%
af = df['Awards'].str[0:-1].str.split('.', return_type='frame')
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: the return_type='frame' keyword is deprecated, use expand=True instead
#   if __name__ == '__main__':

# %%
af.head()
# Out:
#                         0                                   1
# 0            Won 3 Oscars   Another 87 wins & 131 nominations
# 1  Nominated for 2 Oscars      Another 5 wins & 6 nominations
# 2            Won 4 Oscars    Another 30 wins & 23 nominations
# 3            Won 7 Oscars     Another 23 wins & 7 nominations
# 4   Nominated for 1 Oscar    Another 34 wins & 75 nominations

# %%
af=af.dropna(axis=0)

# %%
af.rename( columns={0: "Oscars", 1: "Other"})
# Out:
#                             Oscars                                Other
# 0                     Won 3 Oscars    Another 87 wins & 131 nominations
# 1           Nominated for 2 Oscars       Another 5 wins & 6 nominations
# 2                     Won 4 Oscars     Another 30 wins & 23 nominations
# 3                     Won 7 Oscars      Another 23 wins & 7 nominations
# 4            Nominated for 1 Oscar     Another 34 wins & 75 nominations
# 5                     Won 3 Oscars    Another 75 wins & 160 nominations
# 7           Won 1 BAFTA Film Award                       Another 5 wins
# 8            Nominated for 1 Oscar        Another 4 wins & 1 nomination
# 9                      Won 1 Oscar     Another 46 wins & 58 nominations
# 10                    Won 6 Oscars     Another 16 wins & 17 nominations
# 11                     Won 1 Oscar     Another 13 wins & 38 nominations
# 12   Nominated for 2 Golden Globes      Another 6 wins & 54 nominations
# ...

# %%
lookup = ['Won']
af['won_oscars'] = np.where(df['oscars'].isin(lookup), 1, 0)
af
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-158-a71c6485cae2> in <module>()
#       1 lookup = ['Won']
# ----> 2 af['won_oscars'] = np.where(df['oscars'].isin(lookup), 1, 0)
#       3 af
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# ...

# %%
term = "Oscar" #term we want to search for
input = af.Oscars() #read input from user

words = af.Oscars.split() #split the sentence into individual words

if term in words: #see if one of the words in the sentence is the word we want
    do_stuff()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-162-5c10f5fa409c> in <module>()
#       1 term = "Oscar" #term we want to search for
# ----> 2 input = af.Oscars() #read input from user
#       3
#       4 words = af.Oscars.split() #split the sentence into individual words
#       5
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Oscars'
